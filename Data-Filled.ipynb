# %% [markdown]
# # Data Manipulation in Python
# ## Workflow
# This is only a sample, very basic workflow. There will be resources at the end for material that explores this subject in a lot more depth.
#
# There's a lot more that can be done, and a lot more tools that can be used.
#
# 1. Download CSV
# 1. Import data into a Pandas Dataframe
# 1. Clean it up
# 1. Extract slices of data
# 1. Data Visualization (next section)

# %% [markdown]
# ## Downloading some interesting Data
# Datasets can come in many formats, notably as CSVs, Excel Files, connection to databases, SQLite Database files, HP5 files and so, so many others.
# We'll be using some simple CSV data.
#
# ### Our dataset
# For this workshop, we'll be working with a dataset that's commonly used for these sort of tutorials. It's a database of the top 5000 movies from TMDb which is a more tolerant competitor to IMDb which doesn't send DMCA takedown requests to people who scrape their website.
#
# The dataset is available on Kaggle at https://www.kaggle.com/tmdb/tmdb-movie-metadata

# %% [markdown]
# We normally would need to download the file, but I've added the file we need to our repository so that we don't need to do anything.
#
# The commands below should work just fine on the cloud environments and on non-Windows environments.

# %%
#!mkdir sources
#!curl -o sources/tmdb-5000-movie-dataset.zip https://marcolussetti.com/workshops/python4data2017/sources/tmdb-5000-movie-dataset.zip

# %%
#!unzip sources/tmdb-5000-movie-dataset.zip -d sources/

# %%
#!ls sources/*.csv

# %% [markdown]
# Now that we have a csv file downloaded in the sources directory, we can import into Pandas.

# %%
import pandas as pd

# %%
dataframe = pd.DataFrame.from_csv('sources/tmdb_5000_movies.csv')
dataframe
# Out:
#                                                       genres  \
# budget
# 237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 258000000  [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# 260000000  [{"id": 16, "name": "Animation"}, {"id": 10751...
# 280000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 250000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 250000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 270000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 200000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 200000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 255000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 225000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 225000000  [{"id": 12, "name": "Adventure"}, {"id": 10751...
# 220000000  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 380000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 225000000  [{"id": 28, "name": "Action"}, {"id": 35, "nam...
# 250000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 215000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 200000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 250000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 180000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 207000000  [{"id": 12, "name": "Adventure"}, {"id": 18, "...
# 200000000  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 250000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 209000000  [{"id": 53, "name": "Thriller"}, {"id": 28, "n...
# 150000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 200000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...                                                      ...
# 27000                         [{"id": 35, "name": "Comedy"}]
# 27000      [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 0          [{"id": 18, "name": "Drama"}, {"id": 35, "name...
# 0          [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 0                              [{"id": 18, "name": "Drama"}]
# 0          [{"id": 28, "name": "Action"}, {"id": 18, "nam...
# 0                             [{"id": 35, "name": "Comedy"}]
# 0          [{"id": 53, "name": "Thriller"}, {"id": 80, "n...
# 22000      [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 0          [{"id": 18, "name": "Drama"}, {"id": 10751, "n...
# 0          [{"id": 53, "name": "Thriller"}, {"id": 27, "n...
# 0          [{"id": 18, "name": "Drama"}, {"id": 35, "name...
# 0                              [{"id": 18, "name": "Drama"}]
# 0          [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 0          [{"id": 878, "name": "Science Fiction"}, {"id"...
# 12000      [{"id": 27, "name": "Horror"}, {"id": 35, "nam...
# 0                              [{"id": 18, "name": "Drama"}]
# 0          [{"id": 18, "name": "Drama"}, {"id": 10769, "n...
# 13                            [{"id": 27, "name": "Horror"}]
# 20000      [{"id": 80, "name": "Crime"}, {"id": 27, "name...
# 0                              [{"id": 18, "name": "Drama"}]
# 0          [{"id": 53, "name": "Thriller"}, {"id": 27, "n...
# 0                              [{"id": 18, "name": "Drama"}]
# 7000       [{"id": 878, "name": "Science Fiction"}, {"id"...
# 0          [{"id": 10769, "name": "Foreign"}, {"id": 53, ...
# 220000     [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 9000       [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 0          [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 0                                                         []
# 0                        [{"id": 99, "name": "Documentary"}]
#
#                                                     homepage      id  \
# budget
# 237000000                        http://www.avatarmovie.com/   19995
# 300000000       http://disney.go.com/disneypictures/pirates/     285
# 245000000        http://www.sonypictures.com/movies/spectre/  206647
# 250000000                 http://www.thedarkknightrises.com/   49026
# 260000000               http://movies.disney.com/john-carter   49529
# 258000000    http://www.sonypictures.com/movies/spider-man3/     559
# 260000000       http://disney.go.com/disneypictures/tangled/   38757
# 280000000  http://marvel.com/movies/movie/193/avengers_ag...   99861
# 250000000  http://harrypotter.warnerbros.com/harrypottera...     767
# 250000000       http://www.batmanvsupermandawnofjustice.com/  209112
# 270000000                            http://www.superman.com    1452
# 200000000  http://www.mgm.com/view/movie/234/Quantum-of-S...   10764
# 200000000       http://disney.go.com/disneypictures/pirates/      58
# 255000000              http://disney.go.com/the-lone-ranger/   57201
# 225000000                         http://www.manofsteel.com/   49521
# 225000000                                                NaN    2454
# 220000000                  http://marvel.com/avengers_movie/   24428
# 380000000  http://disney.go.com/pirates/index-on-stranger...    1865
# 225000000    http://www.sonypictures.com/movies/meninblack3/   41154
# 250000000                          http://www.thehobbit.com/  122917
# 215000000                 http://www.theamazingspiderman.com    1930
# 200000000                  http://www.robinhoodthemovie.com/   20662
# 250000000                          http://www.thehobbit.com/   57158
# 180000000  http://www.goldencompassmovie.com/index_german...    2268
# 207000000                                                NaN     254
# 200000000                        http://www.titanicmovie.com     597
# 250000000           http://marvel.com/captainamericapremiere  271110
# 209000000                                                NaN   44833
# 150000000                      http://www.jurassicworld.com/  135397
# 200000000                       http://www.skyfall-movie.com   37724
# ...                                                      ...     ...
# 27000                   http://www.miramax.com/movie/clerks/    2292
# 27000                                                    NaN   42497
# 0                                                        NaN   33693
# 0                                                        NaN   14585
# 0                                                        NaN  185465
# 0                                                        NaN   38780
# 0                                                        NaN   14022
# 0                                                        NaN  366967
# 22000                 https://www.facebook.com/DrySpellMovie  255266
# 0                                                        NaN   17345
# 0                                                        NaN  226458
# 0                          http://www.thepuffychairmovie.com   24055
# 0                                                        NaN  287625
# 0                                                        NaN   44990
# 0                                                        NaN   86304
# 12000                                                    NaN     692
# 0                                                        NaN   39851
# 0                                                        NaN   13898
# 13                             http://tincanmanthemovie.com/  157185
# 20000                                                    NaN   36095
# 0                                                        NaN  182291
# 0                                                        NaN  286939
# 0                                                        NaN  124606
# 7000                              http://www.primermovie.com   14337
# 0                                                        NaN   67238
# 220000                                                   NaN    9367
# 9000                                                     NaN   72766
# 0          http://www.hallmarkchannel.com/signedsealeddel...  231617
# 0                                http://shanghaicalling.com/  126186
# 0                                                        NaN   25975
#
#                                                     keywords  \
# budget
# 237000000  [{"id": 1463, "name": "culture clash"}, {"id":...
# 300000000  [{"id": 270, "name": "ocean"}, {"id": 726, "na...
# 245000000  [{"id": 470, "name": "spy"}, {"id": 818, "name...
# 250000000  [{"id": 849, "name": "dc comics"}, {"id": 853,...
# 260000000  [{"id": 818, "name": "based on novel"}, {"id":...
# 258000000  [{"id": 851, "name": "dual identity"}, {"id": ...
# 260000000  [{"id": 1562, "name": "hostage"}, {"id": 2343,...
# 280000000  [{"id": 8828, "name": "marvel comic"}, {"id": ...
# 250000000  [{"id": 616, "name": "witch"}, {"id": 2343, "n...
# 250000000  [{"id": 849, "name": "dc comics"}, {"id": 7002...
# 270000000  [{"id": 83, "name": "saving the world"}, {"id"...
# 200000000  [{"id": 627, "name": "killing"}, {"id": 1568, ...
# 200000000  [{"id": 616, "name": "witch"}, {"id": 663, "na...
# 255000000  [{"id": 1556, "name": "texas"}, {"id": 2673, "...
# 225000000  [{"id": 83, "name": "saving the world"}, {"id"...
# 225000000  [{"id": 818, "name": "based on novel"}, {"id":...
# 220000000  [{"id": 242, "name": "new york"}, {"id": 5539,...
# 380000000  [{"id": 658, "name": "sea"}, {"id": 1316, "nam...
# 225000000  [{"id": 4379, "name": "time travel"}, {"id": 5...
# 250000000  [{"id": 417, "name": "corruption"}, {"id": 603...
# 215000000  [{"id": 1872, "name": "loss of father"}, {"id"...
# 200000000  [{"id": 4147, "name": "robin hood"}, {"id": 43...
# 250000000  [{"id": 603, "name": "elves"}, {"id": 604, "na...
# 180000000  [{"id": 392, "name": "england"}, {"id": 1461, ...
# 207000000  [{"id": 774, "name": "film business"}, {"id": ...
# 200000000  [{"id": 2580, "name": "shipwreck"}, {"id": 298...
# 250000000  [{"id": 393, "name": "civil war"}, {"id": 6091...
# 209000000  [{"id": 1721, "name": "fight"}, {"id": 4410, "...
# 150000000  [{"id": 1299, "name": "monster"}, {"id": 1718,...
# 200000000  [{"id": 470, "name": "spy"}, {"id": 4289, "nam...
# ...                                                      ...
# 27000      [{"id": 1361, "name": "salesclerk"}, {"id": 30...
# 27000      [{"id": 1566, "name": "dream"}, {"id": 13059, ...
# 0                     [{"id": 171993, "name": "mumblecore"}]
# 0          [{"id": 1438, "name": "office"}, {"id": 9673, ...
# 0                                                         []
# 0          [{"id": 10022, "name": "rampage"}, {"id": 1454...
# 0          [{"id": 305, "name": "moon"}, {"id": 490, "nam...
# 0                                                         []
# 22000      [{"id": 13043, "name": "dating"}, {"id": 15160...
# 0          [{"id": 186, "name": "christianity"}, {"id": 4...
# 0                       [{"id": 9712, "name": "possession"}]
# 0                     [{"id": 171993, "name": "mumblecore"}]
# 0                                                         []
# 0                [{"id": 10183, "name": "independent film"}]
# 0                        [{"id": 9715, "name": "superhero"}]
# 12000      [{"id": 237, "name": "gay"}, {"id": 900, "name...
# 0          [{"id": 6782, "name": "addiction"}, {"id": 155...
# 0                                                         []
# 13                  [{"id": 14903, "name": "home invasion"}]
# 20000      [{"id": 233, "name": "japan"}, {"id": 549, "na...
# 0          [{"id": 718, "name": "confession"}, {"id": 100...
# 0                                                         []
# 0          [{"id": 10726, "name": "gang"}, {"id": 33928, ...
# 7000       [{"id": 1448, "name": "distrust"}, {"id": 2101...
# 0                                                         []
# 220000     [{"id": 5616, "name": "united states\u2013mexi...
# 9000                                                      []
# 0          [{"id": 248, "name": "date"}, {"id": 699, "nam...
# 0                                                         []
# 0          [{"id": 1523, "name": "obsession"}, {"id": 224...
#
#           original_language                               original_title  \
# budget
# 237000000                en                                       Avatar
# 300000000                en     Pirates of the Caribbean: At World's End
# 245000000                en                                      Spectre
# 250000000                en                        The Dark Knight Rises
# 260000000                en                                  John Carter
# 258000000                en                                 Spider-Man 3
# 260000000                en                                      Tangled
# 280000000                en                      Avengers: Age of Ultron
# 250000000                en       Harry Potter and the Half-Blood Prince
# 250000000                en           Batman v Superman: Dawn of Justice
# 270000000                en                             Superman Returns
# 200000000                en                            Quantum of Solace
# 200000000  When soldier Robin happens upon the dying Robe...   37.668301
# 250000000  The Dwarves, Bilbo and Gandalf have successful...   94.370564
# 180000000  After overhearing a shocking secret, precociou...   42.990906
# 207000000  In 1933 New York, an overly ambitious movie pr...   61.226010
# 200000000  84 years later, a 101-year-old woman named Ros...  100.025899
# 250000000  Following the events of Age of Ultron, the col...  198.372395
# 209000000  When mankind beams a radio signal into space, ...   64.928382
# 150000000  Twenty-two years after the events of Jurassic ...  418.708552
# 200000000  When Bond's latest assignment goes gravely wro...   93.004993
# ...                                                      ...         ...
# 27000      Convenience and video store clerks Dante and R...   19.748658
# 27000      An erotic poem set in the fantasies of a young...    0.027811
# 0          Unsure of what to do next, 23-year-old Marnie ...    0.362633
# 0          Two business executives--one an avowed misogyn...    2.634007
# 0          Fifteen years ago, their Washington Heights ne...    0.039264
# 0          The boredom of small town life is eating Bill ...    7.101197
# 0          Presents a day in the life in Austin, Texas am...    3.320622
# 0          A desperate ex-con is forced to gather his old...    0.038143
# 22000      Sasha tries to get her soon-to-be ex husband K...    0.048948
# 0          Jay Austin wants to sell you a used car, but w...    1.048524
# 0          During an all-night, drug-fueled party at an a...    3.619167
# 0          Josh's life is pretty much in the toilet. He's...    1.243955
# 0          Created by the members of a Nairobi-based arts...    0.327794
# 0          'Breaking Upwards' explores a young, real-life...    0.674570
# 0          Masked vigilantes Charge (Jason Trost), Cutthr...    3.545991
# 12000      Notorious Baltimore criminal and underground f...    4.553644
# 0          After losing her husband to a heroin overdose,...    1.464566
# 0          Various women struggle to function in the oppr...    1.193779
# 13         Recently dumped by his girlfirend for another ...    0.332679
# 20000      A wave of gruesome murders is sweeping Tokyo. ...    0.212443
# 0          Isaac and Angel are two young Latinos involved...    0.029757
# 0          It should have been just a normal day of sex, ...    0.166513
# 0          A young woman in L.A. is having a bad day: she...    0.918116
# 7000       Friends/fledgling entrepreneurs invent a devic...   23.307949
# 0          Adam, a security guard, travels from Californi...    0.022173
# 220000     El Mariachi just wants to play his guitar and ...   14.269792
# 9000       A newlywed couple's honeymoon is upended by th...    0.642552
# 0          "Signed, Sealed, Delivered" introduces a dedic...    1.444476
# 0          When ambitious New York attorney Sam is sent t...    0.857008
# 0          Ever since the second grade when he first saw ...    1.929883
#
#                                         production_companies  \
# budget
# 237000000  [{"name": "Ingenious Film Partners", "id": 289...
# 300000000  [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 245000000  [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 250000000  [{"name": "Legendary Pictures", "id": 923}, {"...
# 260000000        [{"name": "Walt Disney Pictures", "id": 2}]
# 258000000  [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 260000000  [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 280000000  [{"name": "Marvel Studios", "id": 420}, {"name...
# 250000000  [{"name": "Warner Bros.", "id": 6194}, {"name"...
# 250000000  [{"name": "DC Comics", "id": 429}, {"name": "A...
# 270000000  [{"name": "DC Comics", "id": 429}, {"name": "L...
# 200000000          [{"name": "Eon Productions", "id": 7576}]
# 200000000  [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 255000000  [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 225000000  [{"name": "Legendary Pictures", "id": 923}, {"...
# 225000000  [{"name": "Walt Disney", "id": 5888}, {"name":...
# 220000000  [{"name": "Paramount Pictures", "id": 4}, {"na...
# 380000000  [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 225000000  [{"name": "Amblin Entertainment", "id": 56}, {...
# 250000000  [{"name": "WingNut Films", "id": 11}, {"name":...
# 215000000  [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 200000000  [{"name": "Imagine Entertainment", "id": 23}, ...
# 250000000  [{"name": "WingNut Films", "id": 11}, {"name":...
# 180000000  [{"name": "New Line Cinema", "id": 12}, {"name...
# 207000000  [{"name": "WingNut Films", "id": 11}, {"name":...
# 200000000  [{"name": "Paramount Pictures", "id": 4}, {"na...
# 250000000  [{"name": "Studio Babelsberg", "id": 264}, {"n...
# 209000000  [{"name": "Universal Pictures", "id": 33}, {"n...
# 150000000  [{"name": "Universal Studios", "id": 13}, {"na...
# 200000000           [{"name": "Columbia Pictures", "id": 5}]
# ...                                                      ...
# 27000      [{"name": "Miramax Films", "id": 14}, {"name":...
# 27000             [{"name": "Strand Releasing", "id": 3923}]
# 0                                                         []
# 0          [{"name": "Alliance Atlantis Communications", ...
# 0                                                         []
# 0          [{"name": "Boll Kino Beteiligungs GmbH & Co. K...
# 0                                                         []
# 0                                                         []
# 22000                                                     []
# 0                                                         []
# 0          [{"name": "GO Productions", "id": 2943}, {"nam...
# 0                                                         []
# 0                                                         []
# 0                                                         []
# 0                       [{"name": "Grindfest", "id": 18818}]
# 12000         [{"name": "Dreamland Productions", "id": 407}]
# 0                                                         []
# 0          [{"name": "Jafar Panahi Film Productions", "id...
# 13         [{"name": "Park Films", "id": 21871}, {"name":...
# 20000                 [{"name": "Daiei Studios", "id": 881}]
# 0                [{"name": "Iconoclast Films", "id": 26677}]
# 0          [{"name": "Gold Lion Films", "id": 37870}, {"n...
# 0          [{"name": "Asylum Films", "id": 10571}, {"name...
# 7000                      [{"name": "Thinkfilm", "id": 446}]
# 0                                                         []
# 220000              [{"name": "Columbia Pictures", "id": 5}]
# 9000                                                      []
# 0          [{"name": "Front Street Pictures", "id": 3958}...
# 0                                                         []
# 0          [{"name": "rusty bear entertainment", "id": 87...
#
#                                         production_countries release_date  \
# budget
# 237000000  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10
# 300000000  [{"iso_3166_1": "US", "name": "United States o...   2007-05-19
# 245000000  [{"iso_3166_1": "GB", "name": "United Kingdom"...   2015-10-26
# 250000000  [{"iso_3166_1": "US", "name": "United States o...   2012-07-16
# 260000000  [{"iso_3166_1": "US", "name": "United States o...   2012-03-07
# 258000000  [{"iso_3166_1": "US", "name": "United States o...   2007-05-01
# 260000000  [{"iso_3166_1": "US", "name": "United States o...   2010-11-24
# 280000000  [{"iso_3166_1": "US", "name": "United States o...   2015-04-22
# 250000000  [{"iso_3166_1": "GB", "name": "United Kingdom"...   2009-07-07
# 250000000  [{"iso_3166_1": "US", "name": "United States o...   2016-03-23
# 270000000  [{"iso_3166_1": "US", "name": "United States o...   2006-06-28
# 200000000  [{"iso_3166_1": "GB", "name": "United Kingdom"...   2008-10-30
# 200000000  [{"iso_3166_1": "JM", "name": "Jamaica"}, {"is...   2006-06-20
# 255000000  [{"iso_3166_1": "US", "name": "United States o...   2013-07-03
# 225000000  [{"iso_3166_1": "GB", "name": "United Kingdom"...   2013-06-12
# 225000000  [{"iso_3166_1": "CZ", "name": "Czech Republic"...   2008-05-15
# 220000000  [{"iso_3166_1": "US", "name": "United States o...   2012-04-25
# 380000000  [{"iso_3166_1": "US", "name": "United States o...   2011-05-14
# 225000000  [{"iso_3166_1": "US", "name": "United States o...   2012-05-23
# 250000000  [{"iso_3166_1": "NZ", "name": "New Zealand"}, ...   2014-12-10
# 215000000  [{"iso_3166_1": "US", "name": "United States o...   2012-06-27
# 200000000  [{"iso_3166_1": "GB", "name": "United Kingdom"...   2010-05-12
# 250000000  [{"iso_3166_1": "NZ", "name": "New Zealand"}, ...   2013-12-11
# 180000000  [{"iso_3166_1": "GB", "name": "United Kingdom"...   2007-12-04
# 207000000  [{"iso_3166_1": "NZ", "name": "New Zealand"}, ...   2005-12-14
# 200000000  [{"iso_3166_1": "US", "name": "United States o...   1997-11-18
# 250000000  [{"iso_3166_1": "US", "name": "United States o...   2016-04-27
# 209000000  [{"iso_3166_1": "US", "name": "United States o...   2012-04-11
# 150000000  [{"iso_3166_1": "US", "name": "United States o...   2015-06-09
# 200000000  [{"iso_3166_1": "GB", "name": "United Kingdom"...   2012-10-25
# ...                                                      ...          ...
# 27000      [{"iso_3166_1": "US", "name": "United States o...   1994-09-13
# 27000      [{"iso_3166_1": "US", "name": "United States o...   1971-01-01
# 0          [{"iso_3166_1": "US", "name": "United States o...   2002-09-20
# 0          [{"iso_3166_1": "CA", "name": "Canada"}, {"iso...   1997-01-19
# 0          [{"iso_3166_1": "US", "name": "United States o...   2002-01-15
# 0          [{"iso_3166_1": "CA", "name": "Canada"}, {"iso...   2009-08-14
# 0          [{"iso_3166_1": "US", "name": "United States o...   1990-07-27
# 0                                                         []   2015-10-02
# 22000      [{"iso_3166_1": "US", "name": "United States o...   2013-02-14
# 0          [{"iso_3166_1": "US", "name": "United States o...   2003-01-01
# 0          [{"iso_3166_1": "US", "name": "United States o...   2015-01-16
# 0                                                         []   2005-01-17
# 0                    [{"iso_3166_1": "KE", "name": "Kenya"}]   2014-09-05
# 0          [{"iso_3166_1": "US", "name": "United States o...   2009-03-14
# 0                                                         []   2011-10-26
# 12000      [{"iso_3166_1": "US", "name": "United States o...   1972-03-12
# 0          [{"iso_3166_1": "GB", "name": "United Kingdom"...   2004-09-01
# 0                     [{"iso_3166_1": "IR", "name": "Iran"}]   2000-09-08
# 13                 [{"iso_3166_1": "IE", "name": "Ireland"}]   2007-01-01
# 20000                [{"iso_3166_1": "JP", "name": "Japan"}]   1997-11-06
# 0          [{"iso_3166_1": "US", "name": "United States o...   2004-04-11
# 0          [{"iso_3166_1": "US", "name": "United States o...   2012-01-20
# 0          [{"iso_3166_1": "US", "name": "United States o...   1995-09-09
# 7000       [{"iso_3166_1": "US", "name": "United States o...   2004-10-08
# 0                                                         []   2005-03-12
# 220000     [{"iso_3166_1": "MX", "name": "Mexico"}, {"iso...   1992-09-04
# 9000                                                      []   2011-12-26
# 0          [{"iso_3166_1": "US", "name": "United States o...   2013-10-13
# 0          [{"iso_3166_1": "US", "name": "United States o...   2012-05-03
# 0          [{"iso_3166_1": "US", "name": "United States o...   2005-08-05
#
#               revenue  runtime  \
# budget
# 237000000  2787965087    162.0
# 300000000   961000000    169.0
# 245000000   880674609    148.0
# 250000000  1084939099    165.0
# 260000000   284139100    132.0
# 258000000   890871626    139.0
# 260000000   591794936    100.0
# 280000000  1405403694    141.0
# 250000000   933959197    153.0
# 250000000   873260194    151.0
# 270000000   391081192    154.0
# 200000000   586090727    106.0
# 200000000  1065659812    151.0
# 255000000    89289910    149.0
# 225000000   662845518    143.0
# 225000000   419651413    150.0
# 220000000  1519557910    143.0
# 380000000  1045713802    136.0
# 225000000   624026776    106.0
# 250000000   956019788    144.0
# 215000000   752215857    136.0
# 200000000   310669540    140.0
# 250000000   958400000    161.0
# 180000000   372234864    113.0
# 207000000   550000000    187.0
# 200000000  1845034188    194.0
# 250000000  1153304495    147.0
# 209000000   303025485    131.0
# 150000000  1513528810    124.0
# 200000000  1108561013    143.0
# ...               ...      ...
# 27000         3151130     92.0
# 27000               0     64.0
# 0               76901     85.0
# 0                   0     97.0
# 0                   0     78.0
# 0                   0     85.0
# 0                   0     97.0
# 0                   0     90.0
# 22000               0     90.0
# 0                   0    120.0
# 0                   0     91.0
# 0                   0     85.0
# 0                   0     60.0
# 0                   0     88.0
# 0                   0     78.0
# 12000         6000000     93.0
# 0                   0    111.0
# 0                   0     90.0
# 13                  0     84.0
# 20000           99000    111.0
# 0                   0     90.0
# 0                   0     82.0
# 0                   0     98.0
# 7000           424760     77.0
# 0                   0     80.0
# 220000        2040920     81.0
# 9000                0     85.0
# 0                   0    120.0
# 0                   0     98.0
# 0                   0     90.0
#
#                                             spoken_languages    status  \
# budget
# 237000000  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 300000000           [{"iso_639_1": "en", "name": "English"}]  Released
# 245000000  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 250000000           [{"iso_639_1": "en", "name": "English"}]  Released
# 260000000           [{"iso_639_1": "en", "name": "English"}]  Released
# 258000000  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 260000000           [{"iso_639_1": "en", "name": "English"}]  Released
# 280000000           [{"iso_639_1": "en", "name": "English"}]  Released
# 250000000           [{"iso_639_1": "en", "name": "English"}]  Released
# 250000000           [{"iso_639_1": "en", "name": "English"}]  Released
# 270000000  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 200000000  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 200000000  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 255000000           [{"iso_639_1": "en", "name": "English"}]  Released
# 225000000           [{"iso_639_1": "en", "name": "English"}]  Released
# 225000000           [{"iso_639_1": "en", "name": "English"}]  Released
# 220000000           [{"iso_639_1": "en", "name": "English"}]  Released
# 380000000  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 225000000           [{"iso_639_1": "en", "name": "English"}]  Released
# 250000000           [{"iso_639_1": "en", "name": "English"}]  Released
# 215000000           [{"iso_639_1": "en", "name": "English"}]  Released
# 200000000  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 250000000           [{"iso_639_1": "en", "name": "English"}]  Released
# 180000000  [{"iso_639_1": "is", "name": "\u00cdslenska"},...  Released
# 207000000           [{"iso_639_1": "en", "name": "English"}]  Released
# 200000000  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 250000000  [{"iso_639_1": "ro", "name": "Rom\u00e2n\u0103...  Released
# 209000000  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 150000000           [{"iso_639_1": "en", "name": "English"}]  Released
# 200000000           [{"iso_639_1": "en", "name": "English"}]  Released
# ...                                                      ...       ...
# 27000               [{"iso_639_1": "en", "name": "English"}]  Released
# 27000      [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 0                   [{"iso_639_1": "en", "name": "English"}]  Released
# 0                   [{"iso_639_1": "en", "name": "English"}]  Released
# 0          [{"iso_639_1": "es", "name": "Espa\u00f1ol"}, ...  Released
# 0                   [{"iso_639_1": "en", "name": "English"}]  Released
# 0                   [{"iso_639_1": "en", "name": "English"}]  Released
# 0                                                         []  Released
# 22000               [{"iso_639_1": "en", "name": "English"}]  Released
# 0                   [{"iso_639_1": "en", "name": "English"}]  Released
# 0                   [{"iso_639_1": "en", "name": "English"}]  Released
# 0                                                         []  Released
# 0          [{"iso_639_1": "sw", "name": "Kiswahili"}, {"i...  Released
# 0                   [{"iso_639_1": "en", "name": "English"}]  Released
# 0                   [{"iso_639_1": "en", "name": "English"}]  Released
# 12000               [{"iso_639_1": "en", "name": "English"}]  Released
# 0          [{"iso_639_1": "cn", "name": "\u5e7f\u5dde\u8b...  Released
# 0          [{"iso_639_1": "fa", "name": "\u0641\u0627\u06...  Released
# 13                  [{"iso_639_1": "en", "name": "English"}]  Released
# 20000      [{"iso_639_1": "ja", "name": "\u65e5\u672c\u8a...  Released
# 0                                                         []  Released
# 0                   [{"iso_639_1": "en", "name": "English"}]  Released
# 0                   [{"iso_639_1": "en", "name": "English"}]  Released
# 7000                [{"iso_639_1": "en", "name": "English"}]  Released
# 0                                                         []  Released
# 220000         [{"iso_639_1": "es", "name": "Espa\u00f1ol"}]  Released
# 9000                                                      []  Released
# 0                   [{"iso_639_1": "en", "name": "English"}]  Released
# 0                   [{"iso_639_1": "en", "name": "English"}]  Released
# 0                   [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                                      tagline  \
# budget
# 237000000                        Enter the World of Pandora.
# 300000000     At the end of the world, the adventure begins.
# 245000000                              A Plan No One Escapes
# 250000000                                    The Legend Ends
# 260000000               Lost in our world, found in another.
# 258000000                                 The battle within.
# 260000000           They're taking adventure to new lengths.
# 280000000                                A New Age Has Come.
# 250000000                              Dark Secrets Revealed
# 250000000                                 Justice or revenge
# 270000000                                                NaN
# 200000000      For love, for hate, for justice, for revenge.
# 200000000                                      Jack is back!
# 255000000                            Never Take Off the Mask
# 225000000               You will believe that a man can fly.
# 225000000                               Hope has a new face.
# 220000000                            Some assembly required.
# 380000000                        Live Forever Or Die Trying.
# 225000000                          They are back... in time.
# 250000000  Witness the defining chapter of the Middle-Ear...
# 215000000                           The untold story begins.
# 200000000     Rise and rise again, until lambs become lions.
# 250000000  Beyond darkness... beyond desolation... lies t...
# 180000000  There are worlds beyond our own - the compass ...
# 207000000                    The eighth wonder of the world.
# 200000000          Nothing on Earth could come between them.
# 250000000                                    Divided We Fall
# 209000000                 The Battle for Earth Begins at Sea
# 150000000                                  The park is open.
# 200000000                                Think on your sins.
# ...                                                      ...
# 27000      Just because they serve you doesn't mean they ...
# 27000                 A unique experience in visual fantasy!
# 0                                                        NaN
# 0              Are all men bastards...or just misunderstood?
# 0                                                        NaN
# 0                                     Vengeance is ruthless.
# 0                                                        NaN
# 0                                                        NaN
# 22000           Getting divorced does funny things to a girl
# 0                                                        NaN
# 0                                                 nederlands
# 0                                                        NaN
# 0                                                        NaN
# 0                                                        NaN
# 0                                       May The Best Man Win
# 12000                             An exercise in poor taste.
# 0                  When you don't have a choice, you change.
# 0                                                        NaN
# 13                           Everything You've Heard is True
# 20000                               Madness. Terror. Murder.
# 0                      Two gangs. One secret. One crossroad.
# 0                                                        NaN
# 0                    Sometimes you've got to break the rules
# 7000                      What happens if it actually works?
# 0                                                        NaN
# 220000     He didn't come looking for trouble, but troubl...
# 9000       A newlywed couple's honeymoon is upended by th...
# 0                                                        NaN
# 0                                   A New Yorker in Shanghai
# 0                                                        NaN
#
#                                                  title  vote_average  \
# budget
# 237000000                                       Avatar           7.2
# 300000000     Pirates of the Caribbean: At World's End           6.9
# 245000000                                      Spectre           6.3
# 250000000                        The Dark Knight Rises           7.6
# 260000000                                  John Carter           6.1
# 258000000                                 Spider-Man 3           5.9
# 260000000                                      Tangled           7.4
# 280000000                      Avengers: Age of Ultron           7.3
# 250000000       Harry Potter and the Half-Blood Prince           7.4
# 250000000           Batman v Superman: Dawn of Justice           5.7
# 270000000                             Superman Returns           5.4
# 200000000                            Quantum of Solace           6.1
# 200000000   Pirates of the Caribbean: Dead Man's Chest           7.0
# 255000000                              The Lone Ranger           5.9
# 225000000                                 Man of Steel           6.5
# 225000000     The Chronicles of Narnia: Prince Caspian           6.3
# 220000000                                 The Avengers           7.4
# 380000000  Pirates of the Caribbean: On Stranger Tides           6.4
# 225000000                               Men in Black 3           6.2
# 250000000    The Hobbit: The Battle of the Five Armies           7.1
# 215000000                       The Amazing Spider-Man           6.5
# 200000000                                   Robin Hood           6.2
# 250000000          The Hobbit: The Desolation of Smaug           7.6
# 180000000                           The Golden Compass           5.8
# 207000000                                    King Kong           6.6
# 200000000                                      Titanic           7.5
# 250000000                   Captain America: Civil War           7.1
# 209000000                                   Battleship           5.5
# 150000000                               Jurassic World           6.5
# 200000000                                      Skyfall           6.9
# ...                                                ...           ...
# 27000                                           Clerks           7.4
# 27000                                   Pink Narcissus           6.0
# 0                                          Funny Ha Ha           6.3
# 0                                In the Company of Men           6.8
# 0                                               Manito           5.5
# 0                                              Rampage           6.0
# 0                                              Slacker           6.4
# 0                                          Dutch Kills           0.0
# 22000                                        Dry Spell           6.0
# 0                                             Flywheel           6.8
# 0                                             Backmask           4.7
# 0                                      The Puffy Chair           6.2
# 0                                 Stories of Our Lives           0.0
# 0                                     Breaking Upwards           5.6
# 0                             All Superheroes Must Die           4.2
# 12000                                   Pink Flamingos           6.2
# 0                                                Clean           6.7
# 0                                           The Circle           6.6
# 13                                         Tin Can Man           2.0
# 20000                                             Cure           7.4
# 0                                       On The Downlow           6.0
# 0                         Sanctuary: Quite a Conundrum           0.0
# 0                                                 Bang           6.0
# 7000                                            Primer           6.9
# 0                                               Cavite           7.5
# 220000                                     El Mariachi           6.6
# 9000                                         Newlyweds           5.9
# 0                            Signed, Sealed, Delivered           7.0
# 0                                     Shanghai Calling           5.7
# 0                                    My Date with Drew           6.3
#
#            vote_count
# budget
# 237000000       11800
# 300000000        4500
# 245000000        4466
# 250000000        9106
# 260000000        2124
# 258000000        3576
# 260000000        3330
# 280000000        6767
# 250000000        5293
# 250000000        7004
# 270000000        1400
# 200000000        2965
# 200000000        5246
# 255000000        2311
# 225000000        6359
# 225000000        1630
# 220000000       11776
# 380000000        4948
# 225000000        4160
# 250000000        4760
# 215000000        6586
# 200000000        1398
# 250000000        4524
# 180000000        1303
# 207000000        2337
# 200000000        7562
# 250000000        7241
# 209000000        2114
# 150000000        8662
# 200000000        7604
# ...               ...
# 27000             755
# 27000               9
# 0                   8
# 0                  44
# 0                   2
# 0                 131
# 0                  77
# 0                   0
# 22000               1
# 0                  19
# 0                  79
# 0                  15
# 0                   0
# 0                  12
# 0                  13
# 12000             110
# 0                  17
# 0                  17
# 13                  1
# 20000              63
# 0                   2
# 0                   0
# 0                   1
# 7000              658
# 0                   2
# 220000            238
# 9000                5
# 0                   6
# 0                   7
# 0                  16
#
# [4803 rows x 19 columns]

# %% [markdown]
# ### Cleaning up the data
# What are some issues you can spot with this data, by just glancing at the dataframe above?

# %% [markdown]
# These are the ones I could think of quickly when I prepared the presentation, but I'm sure I missed some:
# - The row index is the budget, whereas it should be the id.
# - There are a lot of columns, do we even need all of them?
# - There are a bunch of movies empty values for some values (indicated by NaN in Pandas)
# - There are movies with a budget of 0
# - There are movies with revenue of 0
# - The genre, keywords, production_company, production_country, language columns contain data in what appears to be JSON structures. Some even include what look like unicode escaping sequences.
# - There are movies with no languages listed (denoted by an empty JSON array)
# - There are movies whose rating is based on thousand of votes, and movies whose rating is based on 5 votes.

# %% [markdown]
# ##### Fixing the index

# %%
dataframe = dataframe.reset_index()
dataframe = dataframe.set_index('id')
dataframe
# Out:
#            budget                                             genres  \
# id
# 19995   237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 285     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 206647  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 49026   250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 49529   260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 559     258000000  [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# 38757   260000000  [{"id": 16, "name": "Animation"}, {"id": 10751...
# 99861   280000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 767     250000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 209112  250000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1452    270000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 10764   200000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 58      200000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 57201   255000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 49521   225000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 2454    225000000  [{"id": 12, "name": "Adventure"}, {"id": 10751...
# 24428   220000000  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 1865    380000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 41154   225000000  [{"id": 28, "name": "Action"}, {"id": 35, "nam...
# 122917  250000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1930    215000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 20662   200000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 57158   250000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2268    180000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 254     207000000  [{"id": 12, "name": "Adventure"}, {"id": 18, "...
# 597     200000000  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 271110  250000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 44833   209000000  [{"id": 53, "name": "Thriller"}, {"id": 28, "n...
# 135397  150000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 37724   200000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...           ...                                                ...
# 2292        27000                     [{"id": 35, "name": "Comedy"}]
# 42497       27000  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 33693           0  [{"id": 18, "name": "Drama"}, {"id": 35, "name...
# 14585           0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 185465          0                      [{"id": 18, "name": "Drama"}]
# 38780           0  [{"id": 28, "name": "Action"}, {"id": 18, "nam...
# 14022           0                     [{"id": 35, "name": "Comedy"}]
# 366967          0  [{"id": 53, "name": "Thriller"}, {"id": 80, "n...
# 255266      22000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 17345           0  [{"id": 18, "name": "Drama"}, {"id": 10751, "n...
# 226458          0  [{"id": 53, "name": "Thriller"}, {"id": 27, "n...
# 24055           0  [{"id": 18, "name": "Drama"}, {"id": 35, "name...
# 287625          0                      [{"id": 18, "name": "Drama"}]
# 44990           0  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 86304           0  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 692         12000  [{"id": 27, "name": "Horror"}, {"id": 35, "nam...
# 39851           0                      [{"id": 18, "name": "Drama"}]
# 13898           0  [{"id": 18, "name": "Drama"}, {"id": 10769, "n...
# 157185         13                     [{"id": 27, "name": "Horror"}]
# 36095       20000  [{"id": 80, "name": "Crime"}, {"id": 27, "name...
# 182291          0                      [{"id": 18, "name": "Drama"}]
# 286939          0  [{"id": 53, "name": "Thriller"}, {"id": 27, "n...
# 124606          0                      [{"id": 18, "name": "Drama"}]
# 14337        7000  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 67238           0  [{"id": 10769, "name": "Foreign"}, {"id": 53, ...
# 9367       220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 72766        9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 231617          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 126186          0                                                 []
# 25975           0                [{"id": 99, "name": "Documentary"}]
#
#                                                  homepage  \
# id
# 19995                         http://www.avatarmovie.com/
# 285          http://disney.go.com/disneypictures/pirates/
# 206647        http://www.sonypictures.com/movies/spectre/
# 49026                  http://www.thedarkknightrises.com/
# 49529                http://movies.disney.com/john-carter
# 559       http://www.sonypictures.com/movies/spider-man3/
# 38757        http://disney.go.com/disneypictures/tangled/
# 99861   http://marvel.com/movies/movie/193/avengers_ag...
# 767     http://harrypotter.warnerbros.com/harrypottera...
# 209112       http://www.batmanvsupermandawnofjustice.com/
# 1452                              http://www.superman.com
# 10764   http://www.mgm.com/view/movie/234/Quantum-of-S...
# 58           http://disney.go.com/disneypictures/pirates/
# 57201               http://disney.go.com/the-lone-ranger/
# 49521                          http://www.manofsteel.com/
# 2454                                                  NaN
# 24428                   http://marvel.com/avengers_movie/
# 1865    http://disney.go.com/pirates/index-on-stranger...
# 41154     http://www.sonypictures.com/movies/meninblack3/
# 122917                          http://www.thehobbit.com/
# 1930                   http://www.theamazingspiderman.com
# 20662                   http://www.robinhoodthemovie.com/
# 57158                           http://www.thehobbit.com/
# 2268    http://www.goldencompassmovie.com/index_german...
# 254                                                   NaN
# 597                           http://www.titanicmovie.com
# 271110           http://marvel.com/captainamericapremiere
# 44833                                                 NaN
# 135397                      http://www.jurassicworld.com/
# 37724                        http://www.skyfall-movie.com
# ...                                                   ...
# 2292                 http://www.miramax.com/movie/clerks/
# 42497                                                 NaN
# 33693                                                 NaN
# 14585                                                 NaN
# 185465                                                NaN
# 38780                                                 NaN
# 14022                                                 NaN
# 366967                                                NaN
# 255266             https://www.facebook.com/DrySpellMovie
# 17345                                                 NaN
# 226458                                                NaN
# 24055                   http://www.thepuffychairmovie.com
# 287625                                                NaN
# 44990                                                 NaN
# 86304                                                 NaN
# 692                                                   NaN
# 39851                                                 NaN
# 13898                                                 NaN
# 157185                      http://tincanmanthemovie.com/
# 36095                                                 NaN
# 182291                                                NaN
# 286939                                                NaN
# 124606                                                NaN
# 14337                          http://www.primermovie.com
# 67238                                                 NaN
# 9367                                                  NaN
# 72766                                                 NaN
# 231617  http://www.hallmarkchannel.com/signedsealeddel...
# 126186                        http://shanghaicalling.com/
# 25975                                                 NaN
#
#                                                  keywords original_language  \
# id
# 19995   [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 285     [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 206647  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 49026   [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 49529   [{"id": 818, "name": "based on novel"}, {"id":...                en
# 559     [{"id": 851, "name": "dual identity"}, {"id": ...                en
# 38757   [{"id": 1562, "name": "hostage"}, {"id": 2343,...                en
# 99861   [{"id": 8828, "name": "marvel comic"}, {"id": ...                en
# 767     [{"id": 616, "name": "witch"}, {"id": 2343, "n...                en
# 209112  [{"id": 849, "name": "dc comics"}, {"id": 7002...                en
# 1452    [{"id": 83, "name": "saving the world"}, {"id"...                en
# 10764   [{"id": 627, "name": "killing"}, {"id": 1568, ...                en
# 58      [{"id": 616, "name": "witch"}, {"id": 663, "na...                en
# 57201   [{"id": 1556, "name": "texas"}, {"id": 2673, "...                en
# 49521   [{"id": 83, "name": "saving the world"}, {"id"...                en
# 2454    [{"id": 818, "name": "based on novel"}, {"id":...                en
# 24428   [{"id": 242, "name": "new york"}, {"id": 5539,...                en
# 1865    [{"id": 658, "name": "sea"}, {"id": 1316, "nam...                en
# 41154   [{"id": 4379, "name": "time travel"}, {"id": 5...                en
# 122917  [{"id": 417, "name": "corruption"}, {"id": 603...                en
# 1930    [{"id": 1872, "name": "loss of father"}, {"id"...                en
# 20662   [{"id": 4147, "name": "robin hood"}, {"id": 43...                en
# 57158   [{"id": 603, "name": "elves"}, {"id": 604, "na...                en
# 2268    [{"id": 392, "name": "england"}, {"id": 1461, ...                en
# 254     [{"id": 774, "name": "film business"}, {"id": ...                en
# 597     [{"id": 2580, "name": "shipwreck"}, {"id": 298...                en
# 271110  [{"id": 393, "name": "civil war"}, {"id": 6091...                en
# 44833   [{"id": 1721, "name": "fight"}, {"id": 4410, "...                en
# 135397  [{"id": 1299, "name": "monster"}, {"id": 1718,...                en
# 37724   [{"id": 470, "name": "spy"}, {"id": 4289, "nam...                en
# ...                                                   ...               ...
# 2292    [{"id": 1361, "name": "salesclerk"}, {"id": 30...                en
# 42497   [{"id": 1566, "name": "dream"}, {"id": 13059, ...                en
# 33693              [{"id": 171993, "name": "mumblecore"}]                en
# 14585   [{"id": 1438, "name": "office"}, {"id": 9673, ...                en
# 185465                                                 []                en
# 38780   [{"id": 10022, "name": "rampage"}, {"id": 1454...                en
# 14022   [{"id": 305, "name": "moon"}, {"id": 490, "nam...                en
# 366967                                                 []                en
# 255266  [{"id": 13043, "name": "dating"}, {"id": 15160...                en
# 17345   [{"id": 186, "name": "christianity"}, {"id": 4...                en
# 226458               [{"id": 9712, "name": "possession"}]                en
# 24055              [{"id": 171993, "name": "mumblecore"}]                en
# 287625                                                 []                en
# 44990         [{"id": 10183, "name": "independent film"}]                en
# 86304                 [{"id": 9715, "name": "superhero"}]                en
# 692     [{"id": 237, "name": "gay"}, {"id": 900, "name...                en
# 39851   [{"id": 6782, "name": "addiction"}, {"id": 155...                en
# 13898                                                  []                fa
# 157185           [{"id": 14903, "name": "home invasion"}]                en
# 36095   [{"id": 233, "name": "japan"}, {"id": 549, "na...                ja
# 182291  [{"id": 718, "name": "confession"}, {"id": 100...                en
# 286939                                                 []                en
# 124606  [{"id": 10726, "name": "gang"}, {"id": 33928, ...                en
# 14337   [{"id": 1448, "name": "distrust"}, {"id": 2101...                en
# 67238                                                  []                en
# 9367    [{"id": 5616, "name": "united states\u2013mexi...                es
# 72766                                                  []                en
# 231617  [{"id": 248, "name": "date"}, {"id": 699, "nam...                en
# 126186                                                 []                en
# 25975   [{"id": 1523, "name": "obsession"}, {"id": 224...                en
#
#                                      original_title  \
# id
# 19995                                        Avatar
# 285        Pirates of the Caribbean: At World's End
# 206647                                      Spectre
# 49026                         The Dark Knight Rises
# 49529                                   John Carter
# 559                                    Spider-Man 3
# 38757                                       Tangled
# 99861                       Avengers: Age of Ultron
# 767          Harry Potter and the Half-Blood Prince
# 209112           Batman v Superman: Dawn of Justice
# 1452                               Superman Returns
# 10764                             Quantum of Solace
# 58       Pirates of the Caribbean: Dead Man's Chest
# 57201                               The Lone Ranger
# 49521                                  Man of Steel
# 2454       The Chronicles of Narnia: Prince Caspian
# 24428                                  The Avengers
# 1865    Pirates of the Caribbean: On Stranger Tides
# 41154                                Men in Black 3
# 122917    The Hobbit: The Battle of the Five Armies
# 1930                         The Amazing Spider-Man
# 20662                                    Robin Hood
# 57158           The Hobbit: The Desolation of Smaug
# 2268                             The Golden Compass
# 254                                       King Kong
# 597                                         Titanic
# 271110                   Captain America: Civil War
# 44833                                    Battleship
# 135397                               Jurassic World
# 37724                                       Skyfall
# ...                                             ...
# 2292                                         Clerks
# 42497                                Pink Narcissus
# 33693                                   Funny Ha Ha
# 14585                         In the Company of Men
# 185465                                       Manito
# 38780                                       Rampage
# 14022                                       Slacker
# 366967                                  Dutch Kills
# 255266                                    Dry Spell
# 17345                                      Flywheel
# 226458                                     Backmask
# 24055                               The Puffy Chair
# 287625                         Stories of Our Lives
# 44990                              Breaking Upwards
# 86304                      All Superheroes Must Die
# 692                                  Pink Flamingos
# 39851                                         Clean
# 13898                                         دایره
# 157185                                  Tin Can Man
# 36095                                           キュア
# 182291                               On The Downlow
# 286939                 Sanctuary: Quite a Conundrum
# 124606                                         Bang
# 14337                                        Primer
# 67238                                        Cavite
# 9367                                    El Mariachi
# 72766                                     Newlyweds
# 231617                    Signed, Sealed, Delivered
# 126186                             Shanghai Calling
# 25975                             My Date with Drew
#
#                                                  overview  popularity  \
# id
# 19995   In the 22nd century, a paraplegic Marine is di...  150.437577
# 285     Captain Barbossa, long believed to be dead, ha...  139.082615
# 206647  A cryptic message from Bond’s past sends him o...  107.376788
# 49026   Following the death of District Attorney Harve...  112.312950
"Signed, Sealed, Delivered" introduces a dedic...    1.444476
# 126186  When ambitious New York attorney Sam is sent t...    0.857008
# 25975   Ever since the second grade when he first saw ...    1.929883
#
#                                      production_companies  \
# id
# 19995   [{"name": "Ingenious Film Partners", "id": 289...
# 285     [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 206647  [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 49026   [{"name": "Legendary Pictures", "id": 923}, {"...
# 49529         [{"name": "Walt Disney Pictures", "id": 2}]
# 559     [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 38757   [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 99861   [{"name": "Marvel Studios", "id": 420}, {"name...
# 767     [{"name": "Warner Bros.", "id": 6194}, {"name"...
# 209112  [{"name": "DC Comics", "id": 429}, {"name": "A...
# 1452    [{"name": "DC Comics", "id": 429}, {"name": "L...
# 10764           [{"name": "Eon Productions", "id": 7576}]
# 58      [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 57201   [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 49521   [{"name": "Legendary Pictures", "id": 923}, {"...
# 2454    [{"name": "Walt Disney", "id": 5888}, {"name":...
# 24428   [{"name": "Paramount Pictures", "id": 4}, {"na...
# 1865    [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 41154   [{"name": "Amblin Entertainment", "id": 56}, {...
# 122917  [{"name": "WingNut Films", "id": 11}, {"name":...
# 1930    [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 20662   [{"name": "Imagine Entertainment", "id": 23}, ...
# 57158   [{"name": "WingNut Films", "id": 11}, {"name":...
# 2268    [{"name": "New Line Cinema", "id": 12}, {"name...
# 254     [{"name": "WingNut Films", "id": 11}, {"name":...
# 597     [{"name": "Paramount Pictures", "id": 4}, {"na...
# 271110  [{"name": "Studio Babelsberg", "id": 264}, {"n...
# 44833   [{"name": "Universal Pictures", "id": 33}, {"n...
# 135397  [{"name": "Universal Studios", "id": 13}, {"na...
# 37724            [{"name": "Columbia Pictures", "id": 5}]
# ...                                                   ...
# 2292    [{"name": "Miramax Films", "id": 14}, {"name":...
# 42497          [{"name": "Strand Releasing", "id": 3923}]
# 33693                                                  []
# 14585   [{"name": "Alliance Atlantis Communications", ...
# 185465                                                 []
# 38780   [{"name": "Boll Kino Beteiligungs GmbH & Co. K...
# 14022                                                  []
# 366967                                                 []
# 255266                                                 []
# 17345                                                  []
# 226458  [{"name": "GO Productions", "id": 2943}, {"nam...
# 24055                                                  []
# 287625                                                 []
# 44990                                                  []
# 86304                [{"name": "Grindfest", "id": 18818}]
# 692        [{"name": "Dreamland Productions", "id": 407}]
# 39851                                                  []
# 13898   [{"name": "Jafar Panahi Film Productions", "id...
# 157185  [{"name": "Park Films", "id": 21871}, {"name":...
# 36095              [{"name": "Daiei Studios", "id": 881}]
# 182291        [{"name": "Iconoclast Films", "id": 26677}]
# 286939  [{"name": "Gold Lion Films", "id": 37870}, {"n...
# 124606  [{"name": "Asylum Films", "id": 10571}, {"name...
# 14337                  [{"name": "Thinkfilm", "id": 446}]
# 67238                                                  []
# 9367             [{"name": "Columbia Pictures", "id": 5}]
# 72766                                                  []
# 231617  [{"name": "Front Street Pictures", "id": 3958}...
# 126186                                                 []
# 25975   [{"name": "rusty bear entertainment", "id": 87...
#
#                                      production_countries release_date  \
# id
# 19995   [{"iso_3166_1": "US", "name": "United States o...   2009-12-10
# 285     [{"iso_3166_1": "US", "name": "United States o...   2007-05-19
# 206647  [{"iso_3166_1": "GB", "name": "United Kingdom"...   2015-10-26
# 49026   [{"iso_3166_1": "US", "name": "United States o...   2012-07-16
# 49529   [{"iso_3166_1": "US", "name": "United States o...   2012-03-07
# 559     [{"iso_3166_1": "US", "name": "United States o...   2007-05-01
# 38757   [{"iso_3166_1": "US", "name": "United States o...   2010-11-24
# 99861   [{"iso_3166_1": "US", "name": "United States o...   2015-04-22
# 767     [{"iso_3166_1": "GB", "name": "United Kingdom"...   2009-07-07
# 209112  [{"iso_3166_1": "US", "name": "United States o...   2016-03-23
# 1452    [{"iso_3166_1": "US", "name": "United States o...   2006-06-28
# 10764   [{"iso_3166_1": "GB", "name": "United Kingdom"...   2008-10-30
# 58      [{"iso_3166_1": "JM", "name": "Jamaica"}, {"is...   2006-06-20
# 57201   [{"iso_3166_1": "US", "name": "United States o...   2013-07-03
# 49521   [{"iso_3166_1": "GB", "name": "United Kingdom"...   2013-06-12
# 2454    [{"iso_3166_1": "CZ", "name": "Czech Republic"...   2008-05-15
# 24428   [{"iso_3166_1": "US", "name": "United States o...   2012-04-25
# 1865    [{"iso_3166_1": "US", "name": "United States o...   2011-05-14
# 41154   [{"iso_3166_1": "US", "name": "United States o...   2012-05-23
# 122917  [{"iso_3166_1": "NZ", "name": "New Zealand"}, ...   2014-12-10
# 1930    [{"iso_3166_1": "US", "name": "United States o...   2012-06-27
# 20662   [{"iso_3166_1": "GB", "name": "United Kingdom"...   2010-05-12
# 57158   [{"iso_3166_1": "NZ", "name": "New Zealand"}, ...   2013-12-11
# 2268    [{"iso_3166_1": "GB", "name": "United Kingdom"...   2007-12-04
# 254     [{"iso_3166_1": "NZ", "name": "New Zealand"}, ...   2005-12-14
# 597     [{"iso_3166_1": "US", "name": "United States o...   1997-11-18
# 271110  [{"iso_3166_1": "US", "name": "United States o...   2016-04-27
# 44833   [{"iso_3166_1": "US", "name": "United States o...   2012-04-11
# 135397  [{"iso_3166_1": "US", "name": "United States o...   2015-06-09
# 37724   [{"iso_3166_1": "GB", "name": "United Kingdom"...   2012-10-25
# ...                                                   ...          ...
# 2292    [{"iso_3166_1": "US", "name": "United States o...   1994-09-13
# 42497   [{"iso_3166_1": "US", "name": "United States o...   1971-01-01
# 33693   [{"iso_3166_1": "US", "name": "United States o...   2002-09-20
# 14585   [{"iso_3166_1": "CA", "name": "Canada"}, {"iso...   1997-01-19
# 185465  [{"iso_3166_1": "US", "name": "United States o...   2002-01-15
# 38780   [{"iso_3166_1": "CA", "name": "Canada"}, {"iso...   2009-08-14
# 14022   [{"iso_3166_1": "US", "name": "United States o...   1990-07-27
# 366967                                                 []   2015-10-02
# 255266  [{"iso_3166_1": "US", "name": "United States o...   2013-02-14
# 17345   [{"iso_3166_1": "US", "name": "United States o...   2003-01-01
# 226458  [{"iso_3166_1": "US", "name": "United States o...   2015-01-16
# 24055                                                  []   2005-01-17
# 287625            [{"iso_3166_1": "KE", "name": "Kenya"}]   2014-09-05
# 44990   [{"iso_3166_1": "US", "name": "United States o...   2009-03-14
# 86304                                                  []   2011-10-26
# 692     [{"iso_3166_1": "US", "name": "United States o...   1972-03-12
# 39851   [{"iso_3166_1": "GB", "name": "United Kingdom"...   2004-09-01
# 13898              [{"iso_3166_1": "IR", "name": "Iran"}]   2000-09-08
# 157185          [{"iso_3166_1": "IE", "name": "Ireland"}]   2007-01-01
# 36095             [{"iso_3166_1": "JP", "name": "Japan"}]   1997-11-06
# 182291  [{"iso_3166_1": "US", "name": "United States o...   2004-04-11
# 286939  [{"iso_3166_1": "US", "name": "United States o...   2012-01-20
# 124606  [{"iso_3166_1": "US", "name": "United States o...   1995-09-09
# 14337   [{"iso_3166_1": "US", "name": "United States o...   2004-10-08
# 67238                                                  []   2005-03-12
# 9367    [{"iso_3166_1": "MX", "name": "Mexico"}, {"iso...   1992-09-04
# 72766                                                  []   2011-12-26
# 231617  [{"iso_3166_1": "US", "name": "United States o...   2013-10-13
# 126186  [{"iso_3166_1": "US", "name": "United States o...   2012-05-03
# 25975   [{"iso_3166_1": "US", "name": "United States o...   2005-08-05
#
#            revenue  runtime  \
# id
# 19995   2787965087    162.0
# 285      961000000    169.0
# 206647   880674609    148.0
# 49026   1084939099    165.0
# 49529    284139100    132.0
# 559      890871626    139.0
# 38757    591794936    100.0
# 99861   1405403694    141.0
# 767      933959197    153.0
# 209112   873260194    151.0
# 1452     391081192    154.0
# 10764    586090727    106.0
# 58      1065659812    151.0
# 57201     89289910    149.0
# 49521    662845518    143.0
# 2454     419651413    150.0
# 24428   1519557910    143.0
# 1865    1045713802    136.0
# 41154    624026776    106.0
# 122917   956019788    144.0
# 1930     752215857    136.0
# 20662    310669540    140.0
# 57158    958400000    161.0
# 2268     372234864    113.0
# 254      550000000    187.0
# 597     1845034188    194.0
# 271110  1153304495    147.0
# 44833    303025485    131.0
# 135397  1513528810    124.0
# 37724   1108561013    143.0
# ...            ...      ...
# 2292       3151130     92.0
# 42497            0     64.0
# 33693        76901     85.0
# 14585            0     97.0
# 185465           0     78.0
# 38780            0     85.0
# 14022            0     97.0
# 366967           0     90.0
# 255266           0     90.0
# 17345            0    120.0
# 226458           0     91.0
# 24055            0     85.0
# 287625           0     60.0
# 44990            0     88.0
# 86304            0     78.0
# 692        6000000     93.0
# 39851            0    111.0
# 13898            0     90.0
# 157185           0     84.0
# 36095        99000    111.0
# 182291           0     90.0
# 286939           0     82.0
# 124606           0     98.0
# 14337       424760     77.0
# 67238            0     80.0
# 9367       2040920     81.0
# 72766            0     85.0
# 231617           0    120.0
# 126186           0     98.0
# 25975            0     90.0
#
#                                          spoken_languages    status  \
# id
# 19995   [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 285              [{"iso_639_1": "en", "name": "English"}]  Released
# 206647  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 49026            [{"iso_639_1": "en", "name": "English"}]  Released
# 49529            [{"iso_639_1": "en", "name": "English"}]  Released
# 559     [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 38757            [{"iso_639_1": "en", "name": "English"}]  Released
# 99861            [{"iso_639_1": "en", "name": "English"}]  Released
# 767              [{"iso_639_1": "en", "name": "English"}]  Released
# 209112           [{"iso_639_1": "en", "name": "English"}]  Released
# 1452    [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 10764   [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 58      [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 57201            [{"iso_639_1": "en", "name": "English"}]  Released
# 49521            [{"iso_639_1": "en", "name": "English"}]  Released
# 2454             [{"iso_639_1": "en", "name": "English"}]  Released
# 24428            [{"iso_639_1": "en", "name": "English"}]  Released
# 1865    [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 41154            [{"iso_639_1": "en", "name": "English"}]  Released
# 122917           [{"iso_639_1": "en", "name": "English"}]  Released
# 1930             [{"iso_639_1": "en", "name": "English"}]  Released
# 20662   [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 57158            [{"iso_639_1": "en", "name": "English"}]  Released
# 2268    [{"iso_639_1": "is", "name": "\u00cdslenska"},...  Released
# 254              [{"iso_639_1": "en", "name": "English"}]  Released
# 597     [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 271110  [{"iso_639_1": "ro", "name": "Rom\u00e2n\u0103...  Released
# 44833   [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 135397           [{"iso_639_1": "en", "name": "English"}]  Released
# 37724            [{"iso_639_1": "en", "name": "English"}]  Released
# ...                                                   ...       ...
# 2292             [{"iso_639_1": "en", "name": "English"}]  Released
# 42497   [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 33693            [{"iso_639_1": "en", "name": "English"}]  Released
# 14585            [{"iso_639_1": "en", "name": "English"}]  Released
# 185465  [{"iso_639_1": "es", "name": "Espa\u00f1ol"}, ...  Released
# 38780            [{"iso_639_1": "en", "name": "English"}]  Released
# 14022            [{"iso_639_1": "en", "name": "English"}]  Released
# 366967                                                 []  Released
# 255266           [{"iso_639_1": "en", "name": "English"}]  Released
# 17345            [{"iso_639_1": "en", "name": "English"}]  Released
# 226458           [{"iso_639_1": "en", "name": "English"}]  Released
# 24055                                                  []  Released
# 287625  [{"iso_639_1": "sw", "name": "Kiswahili"}, {"i...  Released
# 44990            [{"iso_639_1": "en", "name": "English"}]  Released
# 86304            [{"iso_639_1": "en", "name": "English"}]  Released
# 692              [{"iso_639_1": "en", "name": "English"}]  Released
# 39851   [{"iso_639_1": "cn", "name": "\u5e7f\u5dde\u8b...  Released
# 13898   [{"iso_639_1": "fa", "name": "\u0641\u0627\u06...  Released
# 157185           [{"iso_639_1": "en", "name": "English"}]  Released
# 36095   [{"iso_639_1": "ja", "name": "\u65e5\u672c\u8a...  Released
# 182291                                                 []  Released
# 286939           [{"iso_639_1": "en", "name": "English"}]  Released
# 124606           [{"iso_639_1": "en", "name": "English"}]  Released
# 14337            [{"iso_639_1": "en", "name": "English"}]  Released
# 67238                                                  []  Released
# 9367        [{"iso_639_1": "es", "name": "Espa\u00f1ol"}]  Released
# 72766                                                  []  Released
# 231617           [{"iso_639_1": "en", "name": "English"}]  Released
# 126186           [{"iso_639_1": "en", "name": "English"}]  Released
# 25975            [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                                   tagline  \
# id
# 19995                         Enter the World of Pandora.
# 285        At the end of the world, the adventure begins.
# 206647                              A Plan No One Escapes
# 49026                                     The Legend Ends
# 49529                Lost in our world, found in another.
# 559                                    The battle within.
# 38757            They're taking adventure to new lengths.
# 99861                                 A New Age Has Come.
# 767                                 Dark Secrets Revealed
# 209112                                 Justice or revenge
# 1452                                                  NaN
# 10764       For love, for hate, for justice, for revenge.
# 58                                          Jack is back!
# 57201                             Never Take Off the Mask
# 49521                You will believe that a man can fly.
# 2454                                 Hope has a new face.
# 24428                             Some assembly required.
# 1865                          Live Forever Or Die Trying.
# 41154                           They are back... in time.
# 122917  Witness the defining chapter of the Middle-Ear...
# 1930                             The untold story begins.
# 20662      Rise and rise again, until lambs become lions.
# 57158   Beyond darkness... beyond desolation... lies t...
# 2268    There are worlds beyond our own - the compass ...
# 254                       The eighth wonder of the world.
# 597             Nothing on Earth could come between them.
# 271110                                    Divided We Fall
# 44833                  The Battle for Earth Begins at Sea
# 135397                                  The park is open.
# 37724                                 Think on your sins.
# ...                                                   ...
# 2292    Just because they serve you doesn't mean they ...
# 42497              A unique experience in visual fantasy!
# 33693                                                 NaN
# 14585       Are all men bastards...or just misunderstood?
# 185465                                                NaN
# 38780                              Vengeance is ruthless.
# 14022                                                 NaN
# 366967                                                NaN
# 255266       Getting divorced does funny things to a girl
# 17345                                                 NaN
# 226458                                         nederlands
# 24055                                                 NaN
# 287625                                                NaN
# 44990                                                 NaN
# 86304                                May The Best Man Win
# 692                            An exercise in poor taste.
{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 41154   [{"id": 28, "name": "Action"}, {"id": 35, "nam...
# 122917  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1930    [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 20662   [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 57158   [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2268    [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 254     [{"id": 12, "name": "Adventure"}, {"id": 18, "...
# 597     [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 271110  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 44833   [{"id": 53, "name": "Thriller"}, {"id": 28, "n...
# 135397  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 37724   [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...                                                   ...
# 2292                       [{"id": 35, "name": "Comedy"}]
# 42497   [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 33693   [{"id": 18, "name": "Drama"}, {"id": 35, "name...
# 14585   [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 185465                      [{"id": 18, "name": "Drama"}]
# 38780   [{"id": 28, "name": "Action"}, {"id": 18, "nam...
# 14022                      [{"id": 35, "name": "Comedy"}]
# 366967  [{"id": 53, "name": "Thriller"}, {"id": 80, "n...
# 255266  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 17345   [{"id": 18, "name": "Drama"}, {"id": 10751, "n...
# 226458  [{"id": 53, "name": "Thriller"}, {"id": 27, "n...
# 24055   [{"id": 18, "name": "Drama"}, {"id": 35, "name...
# 287625                      [{"id": 18, "name": "Drama"}]
# 44990   [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 86304   [{"id": 878, "name": "Science Fiction"}, {"id"...
# 692     [{"id": 27, "name": "Horror"}, {"id": 35, "nam...
# 39851                       [{"id": 18, "name": "Drama"}]
# 13898   [{"id": 18, "name": "Drama"}, {"id": 10769, "n...
# 157185                     [{"id": 27, "name": "Horror"}]
# 36095   [{"id": 80, "name": "Crime"}, {"id": 27, "name...
# 182291                      [{"id": 18, "name": "Drama"}]
# 286939  [{"id": 53, "name": "Thriller"}, {"id": 27, "n...
# 124606                      [{"id": 18, "name": "Drama"}]
# 14337   [{"id": 878, "name": "Science Fiction"}, {"id"...
# 67238   [{"id": 10769, "name": "Foreign"}, {"id": 53, ...
# 9367    [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 72766   [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 231617  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 126186                                                 []
# 25975                 [{"id": 99, "name": "Documentary"}]
#
# [4803 rows x 8 columns]

# %% [markdown]
# #### Exploring data
# Let's look at the what sort of data we're looking at!

# %%
print("Rows", len(dataframe_filtered))

print("Avg budget", round(dataframe_filtered['budget'].mean(), 0),
      "Min budget", dataframe_filtered['budget'].min(), "Max budget", dataframe_filtered['budget'].max())

print("Avg revenue", round(dataframe_filtered['revenue'].mean(), 0),
      "Min revenue", dataframe_filtered['revenue'].min(), "Max revenue", dataframe_filtered['revenue'].max())
# Out:
# Rows 4803
# Avg budget 29045040.0 Min budget 0 Max budget 380000000
# Avg revenue 82260639.0 Min revenue 0 Max revenue 2787965087

# %%
dataframe.describe()
# Out:
#              budget   popularity       revenue      runtime  vote_average  \
# count  4.803000e+03  4803.000000  4.803000e+03  4801.000000   4803.000000
# mean   2.904504e+07    21.492301  8.226064e+07   106.875859      6.092172
# std    4.072239e+07    31.816650  1.628571e+08    22.611935      1.194612
# min    0.000000e+00     0.000000  0.000000e+00     0.000000      0.000000
# 25%    7.900000e+05     4.668070  0.000000e+00    94.000000      5.600000
# 50%    1.500000e+07    12.921594  1.917000e+07   103.000000      6.200000
# 75%    4.000000e+07    28.313505  9.291719e+07   118.000000      6.800000
# max    3.800000e+08   875.581305  2.787965e+09   338.000000     10.000000
#
#          vote_count
# count   4803.000000
# mean     690.217989
# std     1234.585891
# min        0.000000
# 25%       54.000000
# 50%      235.000000
# 75%      737.000000
# max    13752.000000

# %% [markdown]
# Now let's say we can to add a new column, called ROI that tracks the return on the investement.
#
# The formula for ROI is: $\frac{Revenue - Cost}{Cost}$
#
# However, we have several columns where the revenue and or cost are zero, which is obviously not very useful for our calculations. So we need to drop all such movies.

# %%
has_revenue = dataframe_filtered['revenue'] > 0
has_budget = dataframe_filtered['budget'] > 0

# %%
# How many have no votes though?
has_votes = dataframe_filtered['vote_count'] > 0
print("Movies with 0 votes:", len(dataframe_filtered) - len(dataframe_filtered[has_votes]))

has_votes = dataframe_filtered['vote_count'] >= 10
print("Movies with 10 or less votes:", len(dataframe_filtered) - len(dataframe_filtered[has_votes]))
# Out:
# Movies with 0 votes: 62
# Movies with 10 or less votes: 411

# %%
movies_with_revenue = dataframe_filtered[has_budget & has_revenue & has_votes]
movies_with_revenue.describe()
# Out:
#            runtime        budget       revenue  vote_average    vote_count
# count  3186.000000  3.186000e+03  3.186000e+03   3186.000000   3186.000000
# mean    110.831136  4.111187e+07  1.228261e+08      6.320213    990.413685
# std      20.946498  4.450889e+07  1.870525e+08      0.849175   1419.272410
# min      41.000000  1.000000e+00  5.000000e+00      2.300000     10.000000
# 25%      96.000000  1.100000e+07  1.775538e+07      5.800000    188.250000
# 50%     107.000000  2.600000e+07  5.679228e+07      6.300000    483.000000
# 75%     121.000000  5.500000e+07  1.483932e+08      6.900000   1156.500000
# max     338.000000  3.800000e+08  2.787965e+09      8.500000  13752.000000

# %%
print("Rows", len(movies_with_revenue))

print("Avg budget", round(movies_with_revenue['budget'].mean(), 0),
      "Min budget", movies_with_revenue['budget'].min(), "Max budget", movies_with_revenue['budget'].max())

print("Avg revenue", round(movies_with_revenue['revenue'].mean(), 0),
      "Min revenue", movies_with_revenue['revenue'].min(), "Max revenue", movies_with_revenue['revenue'].max())

print("Avg rating", round(movies_with_revenue['vote_average'].mean(), 0),
      "Min rating", movies_with_revenue['vote_average'].min(), "Max rating", movies_with_revenue['vote_average'].max())

print("Avg votes", round(movies_with_revenue['vote_count'].mean(), 0),
      "Min votes", movies_with_revenue['vote_count'].min(), "Max votes", movies_with_revenue['vote_count'].max())

print("Avg runtime", round(movies_with_revenue['runtime'].mean(), 0),
      "Min runtime", movies_with_revenue['runtime'].min(), "Max runtime", movies_with_revenue['runtime'].max())
# Out:
# Rows 3186
# Avg budget 41111874.0 Min budget 1 Max budget 380000000
# Avg revenue 122826134.0 Min revenue 5 Max revenue 2787965087
# Avg rating 6.0 Min rating 2.3 Max rating 8.5
# Avg votes 990.0 Min votes 10 Max votes 13752
# Avg runtime 111.0 Min runtime 41.0 Max runtime 338.0

# %%
# Wait, what sort of movies has 338 minutes runtime?
from datetime import timedelta
print('338 minutes is equivalent to', timedelta(minutes=338), 'hours')
movies_with_revenue.loc[movies_with_revenue['runtime'].idxmax()]
# Out:
# 338 minutes is equivalent to 5:38:00 hours
# title                                                      Carlos
# release_date                                           2010-05-19
# runtime                                                       338
# budget                                                   18000000
# revenue                                                    871279
# vote_average                                                  6.7
# vote_count                                                     50
# genres          [{"id": 80, "name": "Crime"}, {"id": 18, "name...
# Name: 43434, dtype: object

# %% [markdown]
# Now we can create our new ROI column. Let's review the formula:
#
# $\frac{Revenue - Cost}{Cost}$

# %%
pd.options.mode.chained_assignment = None  # Disable warning we don't care about
movies_with_revenue['ROI'] = (movies_with_revenue['revenue'] -
# 2292                                         Clerks   1994-09-13     92.0
# 692                                  Pink Flamingos   1972-03-12     93.0
# 36095                                          Cure   1997-11-06    111.0
# 14337                                        Primer   2004-10-08     77.0
# 9367                                    El Mariachi   1992-09-04     81.0
#
#            budget     revenue  vote_average  vote_count  \
# id
# 19995   237000000  2787965087           7.2       11800
# 285     300000000   961000000           6.9        4500
# 206647  245000000   880674609           6.3        4466
# 49026   250000000  1084939099           7.6        9106
# 49529   260000000   284139100           6.1        2124
# 559     258000000   890871626           5.9        3576
# 38757   260000000   591794936           7.4        3330
# 99861   280000000  1405403694           7.3        6767
# 767     250000000   933959197           7.4        5293
# 209112  250000000   873260194           5.7        7004
# 1452    270000000   391081192           5.4        1400
# 10764   200000000   586090727           6.1        2965
# 58      200000000  1065659812           7.0        5246
# 57201   255000000    89289910           5.9        2311
# 49521   225000000   662845518           6.5        6359
# 2454    225000000   419651413           6.3        1630
# 24428   220000000  1519557910           7.4       11776
# 1865    380000000  1045713802           6.4        4948
# 41154   225000000   624026776           6.2        4160
# 122917  250000000   956019788           7.1        4760
# 1930    215000000   752215857           6.5        6586
# 20662   200000000   310669540           6.2        1398
# 57158   250000000   958400000           7.6        4524
# 2268    180000000   372234864           5.8        1303
# 254     207000000   550000000           6.6        2337
# 597     200000000  1845034188           7.5        7562
# 271110  250000000  1153304495           7.1        7241
# 44833   209000000   303025485           5.5        2114
# 135397  150000000  1513528810           6.5        8662
# 37724   200000000  1108561013           6.9        7604
# ...           ...         ...           ...         ...
# 3060       245000    22000000           7.0          21
# 18533      230000     2260712           6.9         733
# 35073      210000     5000000           6.7          41
# 9659       400000   100000000           6.6        1213
# 10218      200000     4505922           6.8         253
# 391        200000    14500000           7.6         883
# 43595      200000     2200000           5.1          27
# 54897      200000     2295733           6.5          10
# 21334      180000      900000           7.8         112
# 79120        8000      469947           7.4         163
# 55420      100000     1776935           6.8         527
# 5822       150000    15200000           4.6          18
# 39141      150000     2891288           5.5          19
# 5723       160000    20710513           7.3         453
# 1779       160000     6706368           7.4          90
# 84355      125000     3200000           6.5         137
# 339408    8500000    15861566           6.5         178
# 18925      100000    10178331           6.6          64
# 299245     100000    42664410           4.9         361
# 985         10000     7000000           7.5         485
# 473         60000     3221152           7.1         586
# 9372        65000    28575078           6.6         506
# 47607       65000      416498           5.6          59
# 242095    4000000      600896           5.8         631
# 42151       31192       10000           6.3          26
# 2292        27000     3151130           7.4         755
# 692         12000     6000000           6.2         110
# 36095       20000       99000           7.4          63
# 14337        7000      424760           6.9         658
# 9367       220000     2040920           6.6         238
#
#                                                    genres         ROI
# id
# 19995   [{"id": 28, "name": "Action"}, {"id": 12, "nam...   10.763566
# 285     [{"id": 12, "name": "Adventure"}, {"id": 14, "...    2.203333
# 206647  [{"id": 28, "name": "Action"}, {"id": 12, "nam...    2.594590
# 49026   [{"id": 28, "name": "Action"}, {"id": 80, "nam...    3.339756
# 49529   [{"id": 28, "name": "Action"}, {"id": 12, "nam...    0.092843
# 559     [{"id": 14, "name": "Fantasy"}, {"id": 28, "na
{"id": 35, "name": "Comedy"}, {"id": 18, "nam...   18.275253
# 5723    [{"id": 18, "name": "Drama"}, {"id": 10402, "n...  128.440706
# 1779    [{"id": 99, "name": "Documentary"}, {"id": 36,...   40.914800
# 84355   [{"id": 18, "name": "Drama"}, {"id": 35, "name...   24.600000
# 339408                      [{"id": 18, "name": "Drama"}]    0.866067
# 18925                       [{"id": 18, "name": "Drama"}]  100.783310
# 299245  [{"id": 27, "name": "Horror"}, {"id": 53, "nam...  425.644100
# 985     [{"id": 18, "name": "Drama"}, {"id": 14, "name...  699.000000
# 473     [{"id": 9648, "name": "Mystery"}, {"id": 18, "...   52.685867
# 9372    [{"id": 99, "name": "Documentary"}, {"id": 35,...  438.616585
# 47607   [{"id": 10749, "name": "Romance"}, {"id": 35, ...    5.407662
# 242095  [{"id": 53, "name": "Thriller"}, {"id": 878, "...   -0.849776
# 42151   [{"id": 18, "name": "Drama"}, {"id": 28, "name...   -0.679405
# 2292                       [{"id": 35, "name": "Comedy"}]  115.708519
# 692     [{"id": 27, "name": "Horror"}, {"id": 35, "nam...  499.000000
# 36095   [{"id": 80, "name": "Crime"}, {"id": 27, "name...    3.950000
# 14337   [{"id": 878, "name": "Science Fiction"}, {"id"...   59.680000
# 9367    [{"id": 28, "name": "Action"}, {"id": 80, "nam...    8.276909
#
# [3186 rows x 9 columns]

# %%
print("Avg ROI", round(movies_with_revenue['ROI'].mean(), 0),
      "Min ROI", movies_with_revenue['ROI'].min(), "Max ROI", movies_with_revenue['ROI'].max())
# Out:
# Avg ROI 2994.0 Min ROI -0.999999478261 Max ROI 8499999.0

# %%
movies_with_revenue.sort_values('ROI', ascending=False).head()
# Out:
#                          title release_date  runtime  budget    revenue  \
# id
# 3082              Modern Times   1936-02-05     87.0       1    8500000
# 78383                Nurse 3-D   2013-09-28     99.0      10   10000000
# 23827      Paranormal Activity   2007-09-14     86.0   15000  193355800
# 1435                 Tarnation   2003-10-19     91.0     218    1162014
# 2667   The Blair Witch Project   1999-07-14     81.0   60000  248000000
#
#        vote_average  vote_count  \
# id
# 3082            8.1         856
# 78383           4.9         119
# 23827           5.9        1316
# 1435            7.5          22
# 2667            6.3        1055
#
#                                                   genres           ROI
# id
# 3082   [{"id": 18, "name": "Drama"}, {"id": 35, "name...  8.499999e+06
# 78383  [{"id": 27, "name": "Horror"}, {"id": 53, "nam...  9.999990e+05
# 23827  [{"id": 27, "name": "Horror"}, {"id": 9648, "n...  1.288939e+04
# 1435   [{"id": 99, "name": "Documentary"}, {"id": 18,...  5.329339e+03
# 2667   [{"id": 27, "name": "Horror"}, {"id": 9648, "n...  4.132333e+03

# %%
movies_with_revenue[(movies_with_revenue['budget'] < 1000)
                    | (movies_with_revenue['revenue'] < 1000)]
# Out:
#                               title release_date  runtime    budget   revenue  \
# id
# 16340   Rugrats in Paris: The Movie   2000-09-14     78.0        30       103
# 14844               Chasing Liberty   2004-01-09    111.0  23000000        12
# 1613                 The 51st State   2001-12-07     93.0        28        14
# 10397                Angela's Ashes   1999-12-25    145.0        25        13
# 2196             Death at a Funeral   2007-02-09     90.0   9000000        46
# 18475                   The Cookout   2004-09-03     97.0  16000000        12
# 10944                    In the Cut   2003-09-09    119.0  12000000        23
# 28932                      F.I.S.T.   1978-04-26    145.0        11        11
# 217708            Of Horses and Men   2013-08-30     85.0        10        11
# 78383                     Nurse 3-D   2013-09-28     99.0        10  10000000
# 13006                  Split Second   1992-05-01     90.0         7         5
# 22649            A Farewell to Arms   1932-12-08     89.0         4        25
# 3082                   Modern Times   1936-02-05     87.0         1   8500000
# 1435                      Tarnation   2003-10-19     91.0       218   1162014
# 11980                  The Prophecy   1995-09-01     98.0         8        16
# 51942   I Married a Strange Person!   1998-08-28     72.0       250       203
#
#         vote_average  vote_count  \
# id
# 16340            6.0         100
# 14844            6.1         152
# 1613             5.9         173
# 10397            7.0          59
# 2196             6.9         497
# 18475            4.6          10
# 10944            4.6          89
# 28932            6.4          29
# 217708           6.9          26
# 78383            4.9         119
# 13006            5.7          63
# 22649            6.2          28
# 3082             8.1         856
# 1435             7.5          22
# 11980            6.4         138
# 51942            7.5          12
#
#                                                    genres           ROI
# id
# 16340   [{"id": 12, "name": "Adventure"}, {"id": 16, "...  2.433333e+00
# 14844   [{"id": 35, "name": "Comedy"}, {"id": 10749, "... -9.999995e-01
# 1613    [{"id": 53, "name": "Thriller"}, {"id": 28, "n... -5.000000e-01
# 10397                       [{"id": 18, "name": "Drama"}] -4.800000e-01
# 2196    [{"id": 35, "name": "Comedy"}, {"id": 18, "nam... -9.999949e-01
# 18475   [{"id": 35, "name": "Comedy"}, {"id": 18, "nam... -9.999993e-01
# 10944   [{"id": 9648, "name": "Mystery"}, {"id": 53, "... -9.999981e-01
# 28932   [{"id": 18, "name": "Drama"}, {"id": 28, "name...  0.000000e+00
# 217708  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...  1.000000e-01
# 78383   [{"id": 27, "name": "Horror"}, {"id": 53, "nam...  9.999990e+05
# 13006   [{"id": 53, "name": "Thriller"}, {"id": 28, "n... -2.857143e-01
# 22649   [{"id": 18, "name": "Drama"}, {"id": 10749, "n...  5.250000e+00
# 3082    [{"id": 18, "name": "Drama"}, {"id": 35, "name...  8.499999e+06
# 1435    [{"id": 99, "name": "Documentary"}, {"id": 18,...  5.329339e+03
# 11980   [{"id": 14, "name": "Fantasy"}, {"id": 27, "na...  1.000000e+00
# 51942   [{"id": 18, "name": "Drama"}, {"id": 35, "name... -1.880000e-01

# %%
# Let's fix some stuff, the data is from Wikipedia
# Tarnation. This is actually semi-accurate and we can leave it as is.
# We don't have enough info from Wikipedia for both budgets & revenues
movies_to_drop = [217708, 78383, 22649, 11980]
movies_with_revenue.drop(movies_to_drop, inplace=True)

# Budgets were supposed to be in millions
budgets_to_increment = [16340, 1613, 10397, 13006, 3082]
for movie in budgets_to_increment:
    movies_with_revenue.at[movie, 'budget'] = 1000000

# Revenues were supposed to be in millions
revenues_to_increment = [16340, 1613, 10397, 13006, 14844, 2196, 18475, 10944]
for movie in revenues_to_increment:
    movies_with_revenue.at[movie, 'revenue'] *= 1000000

# Budgets are just plain wrong
# F.I.S.T.
movies_with_revenue.at[28932, 'budget'] = 8000000
movies_with_revenue.at[28932, 'revenue'] = 20388920
# I Married a Strange Person!
movies_with_revenue.at[51942, 'budget'] = 250000
movies_with_revenue.at[51942, 'revenue'] = 467272

# Check what's left
movies_with_revenue[(movies_with_revenue['budget'] < 1000)
                    | (movies_with_revenue['revenue'] < 1000)]
# Out:
#           title release_date  runtime  budget  revenue  vote_average  \
# id
# 1435  Tarnation   2003-10-19     91.0     218  1162014           7.5
#
#       vote_count                                             genres  \
# id
# 1435          22  [{"id": 99, "name": "Documentary"}, {"id": 18,...
#
#              ROI
# id
# 1435  5329.33945

# %% [markdown]
# <center>![Tarnation](https://images-na.ssl-images-amazon.com/images/I/51X9ED5D5EL.jpg "Tarnation")</center>

# %%
movies_with_revenue['ROI'] = (movies_with_revenue['revenue'] -
                              movies_with_revenue['budget']) / movies_with_revenue['budget']

print(movies_with_revenue['ROI'].describe())
print()
print(movies_with_revenue.loc[movies_with_revenue['ROI'].idxmax()])
# Out:
# count     3182.000000
# mean        11.867908
# std        258.903084
# min         -0.999744
# 25%          0.058312
# 50%          1.329405
# 75%          3.453665
# max      12889.386667
# Name: ROI, dtype: float64
#
# title                                         Paranormal Activity
# release_date                                           2007-09-14
# runtime                                                        86
# budget                                                      15000
# revenue                                                 193355800
# vote_average                                                  5.9
# vote_count                                                   1316
# genres          [{"id": 27, "name": "Horror"}, {"id": 9648, "n...
# ROI                                                       12889.4
# Name: 23827, dtype: object

# %%
movies_with_revenue.describe()
# Out:
#            runtime        budget       revenue  vote_average    vote_count  \
# count  3182.000000  3.182000e+03  3.182000e+03    3182.00000   3182.000000
# mean    110.853865  4.116772e+07  1.230556e+08       6.32049    991.560968
# std      20.948786  4.450936e+07  1.870819e+08       0.84927   1419.794036
# min      41.000000  2.180000e+02  6.399000e+03       2.30000     10.000000
# 25%      96.000000  1.100000e+07  1.798612e+07       5.80000    189.000000
# 50%     107.000000  2.600000e+07  5.710004e+07       6.30000    484.000000
# 75%     121.000000  5.500000e+07  1.488700e+08       6.90000   1163.000000
# max     338.000000  3.800000e+08  2.787965e+09       8.50000  13752.000000
#
#                 ROI
# count   3182.000000
# mean      11.867908
# std      258.903084
# min       -0.999744
# 25%        0.058312
# 50%        1.329405
# 75%        3.453665
# max    12889.386667

# %%
movies_with_revenue.corr(method='pearson')
# Out:
#                runtime    budget   revenue  vote_average  vote_count       ROI
# runtime       1.000000  0.227413  0.231520      0.392767    0.256679 -0.036856
# budget        0.227413  1.000000  0.703356     -0.042950    0.536696 -0.035303
# revenue       0.231520  0.703356  1.000000      0.186911    0.754587  0.008334
# vote_average  0.392767 -0.042950  0.186911      1.000000    0.383734  0.009563
# vote_count    0.256679  0.536696  0.754587      0.383734    1.000000  0.002203
# ROI          -0.036856 -0.035303  0.008334      0.009563    0.002203  1.000000

# %%
movies_with_revenue['release_date'] = pd.to_datetime(movies_with_revenue['release_date'])

movies_with_revenue['Year'] = movies_with_revenue['release_date'].dt.year
movies_with_revenue['Month'] = movies_with_revenue['release_date'].dt.month
movies_with_revenue.describe()
# Out:
#            runtime        budget       revenue  vote_average    vote_count  \
# count  3182.000000  3.182000e+03  3.182000e+03    3182.00000   3182.000000
# mean    110.853865  4.116772e+07  1.230556e+08       6.32049    991.560968
# std      20.948786  4.450936e+07  1.870819e+08       0.84927   1419.794036
# min      41.000000  2.180000e+02  6.399000e+03       2.30000     10.000000
# 25%      96.000000  1.100000e+07  1.798612e+07       5.80000    189.000000
# 50%     107.000000  2.600000e+07  5.710004e+07       6.30000    484.000000
# 75%     121.000000  5.500000e+07  1.488700e+08       6.90000   1163.000000
# max     338.000000  3.800000e+08  2.787965e+09       8.50000  13752.000000
#
#                 ROI         Year        Month
# count   3182.000000  3182.000000  3182.000000
# mean      11.867908  2001.815525     6.974859
# std      258.903084    13.033759     3.367466
# min       -0.999744  1916.000000     1.000000
# 25%        0.058312  1998.000000     4.000000
# 50%        1.329405  2005.000000     7.000000
# 75%        3.453665  2010.000000    10.000000
# max    12889.386667  2016.000000    12.000000

# %%
movies_with_revenue.corr()
# Out:
#                runtime    budget   revenue  vote_average  vote_count  \
# runtime       1.000000  0.227413  0.231520      0.392767    0.256679
# budget        0.227413  1.000000  0.703356     -0.042950    0.536696
# revenue       0.231520  0.703356  1.000000      0.186911    0.754587
# vote_average  0.392767 -0.042950  0.186911      1.000000    0.383734
# vote_count    0.256679  0.536696  0.754587      0.383734    1.000000
# ROI          -0.036856 -0.035303  0.008334      0.009563    0.002203
# Year         -0.162446  0.267197  0.145366     -0.208644    0.171368
# Month         0.162647  0.019797  0.038818      0.134572    0.021391
#
#                    ROI      Year     Month
# runtime      -0.036856 -0.162446  0.162647
# budget       -0.035303  0.267197  0.019797
# revenue       0.008334  0.145366  0.038818
# vote_average  0.009563 -0.208644  0.134572
# vote_count    0.002203  0.171368  0.021391
# ROI           1.000000 -0.009788  0.014678
# Year         -0.009788  1.000000 -0.071258
# Month         0.014678 -0.071258  1.000000

# %% [markdown]
# # Data Visualization
# Now that we have some semi-useful data, we can experiment with some graphs.
#
# We will use Seaborn and Matplotlib, the standard plotting library in Python.

# %%
# %matplotlib inline
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Seaborn

# %%
# Scatterplot of budget vs revenue
sns.lmplot(x="budget", y="revenue", data=movies_with_revenue)
# sns.lmplot(x="budget", y="revenue", data=movies_with_revenue, scatter_kws={"s": 2})

# %%
# Same scale on both axes
sns.lmplot(x="budget", y="revenue", data=movies_with_revenue)
plt.xlim(0, max(movies_with_revenue['budget'].max(), movies_with_revenue['revenue'].max()))
plt.ylim(0, max(movies_with_revenue['budget'].max(), movies_with_revenue['revenue'].max()))
plt.gca().set_aspect('equal', adjustable='box')

# %%
scaled_values = movies_with_revenue[['budget', 'revenue']].apply(lambda x: x / 1000000)

sns.lmplot(x='budget', y='revenue', data=scaled_values)
plt.xlim(0, max(scaled_values['budget'] + scaled_values['revenue']))
plt.ylim(0, max(scaled_values['budget'] + scaled_values['revenue']))
plt.gca().set_aspect('equal', adjustable='box')

# %%
scaled_values = movies_with_revenue[['budget', 'revenue']].sample(n=50).apply(lambda x: x / 1000000)

sns.lmplot(x='budget', y='revenue', data=scaled_values, fit_reg=False)

# %%
scaled_values = movies_with_revenue[['title', 'budget', 'revenue']].sort_values('revenue', ascending=False)[:25]
scaled_values['budget'] = scaled_values['budget'].apply(lambda x: x / 1000000)
scaled_values['revenue'] = scaled_values['revenue'].apply(lambda x: x / 1000000)
# scaled_values.head()
sns.boxplot(data=scaled_values[['revenue']])

# %%
sns.lmplot(x='budget', y='revenue', data=scaled_values, fit_reg=False)

# %%
scaled_values = movies_with_revenue[['title', 'budget', 'revenue']].sort_values('budget', ascending=False)[:50]
scaled_values['budget'] = scaled_values['budget'].apply(lambda x: x / 1000000)
scaled_values['revenue'] = scaled_values['revenue'].apply(lambda x: x / 1000000)
# scaled_values.head()
sns.boxplot(data=scaled_values[['budget']])

# %%
# Suppose we want to have an idea of what sort of distribution budgets have in our movie dataset
sns.distplot(movies_with_revenue[['budget']].apply(lambda x: x / 1000000))
# plt.xlim(0, max(movies_with_revenue['budget'].apply(lambda x: x / 1000000)))

# %% [markdown]
# ### Matplotlib

# %%
# Prepare data by sorting and splitting into two separate entities per axii
budgets = movies_with_revenue['budget'].apply(lambda x: x / 1000000).tolist()
revenues = movies_with_revenue['revenue'].apply(lambda x: x / 1000000).tolist()

# Monstrosity to be seen later.
#budgets, revenues = zip(*sorted(zip(movies_with_revenue['budget'].apply(lambda x: x / 1000000).tolist(), movies_with_revenue['revenue'].apply(lambda x: x / 1000000).tolist()), key=lambda budget: budget[0], reverse=True))


plt.axis([0, max(budgets), 0, max(revenues)])
plt.plot(budgets, revenues)
plt.xlabel('Budgets')
plt.ylabel('Revenues')
plt.title('Revenues vs Budgets')
plt.draw()

# %%
plt.axis([0, max(budgets), 0, max(revenues)])
plt.scatter(budgets, revenues)
# We can make this more readable by shrinking down the sizes
#plt.scatter(budgets, revenues, s=2)
plt.xlabel('Budgets')
plt.ylabel('Revenues')
plt.title('Revenues vs Budgets')
#plt.gca().set_aspect('equal', adjustable='box')
plt.draw()

# %% [markdown]
# ### Revenue by Genre
#
# Let's try to correlate genres and revenues! As each movie has multiple genre, we'll take the simple approach of duplicating the movie for each genre it exists in.

# %%
list(movies_with_revenue['genres'][:1])
# Out:
# ['[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]']

# %%
def genres_to_sets(json_string):
    input_list = json.loads(json_string)
    return {genre['name'] for genre in input_list}

genres_to_sets(movies_with_revenue['genres'][19995])
# Out:
# {'Action', 'Adventure', 'Fantasy', 'Science Fiction'}

# %%
movies_by_genre = []

for row in movies_with_revenue[['title', 'genres', 'budget', 'revenue', 'ROI']].itertuples():
    for genre in genres_to_sets(row.genres):
        movies_by_genre.append(row._asdict())
        movies_by_genre[-1]['genres'] = genre
        movies_by_genre[-1]['budget'] /= 1000000
        movies_by_genre[-1]['revenue'] /= 1000000
        
movies_by_genre = pd.DataFrame(movies_by_genre)
movies_by_genre.rename(columns={'genres': 'genre'}, inplace=True)
movies_by_genre.head()
# Out:
#    Index                                     title            genre  budget  \
# 0  19995                                    Avatar  Science Fiction   237.0
# 1  19995                                    Avatar        Adventure   237.0
# 2  19995                                    Avatar           Action   237.0
# 3  19995                                    Avatar          Fantasy   237.0
# 4    285  Pirates of the Caribbean: At World's End        Adventure   300.0
#
#        revenue        ROI
# 0  2787.965087  10.763566
# 1  2787.965087  10.763566
# 2  2787.965087  10.763566
# 3  2787.965087  10.763566
# 4   961.000000   2.203333

# %%
sns.set_style('whitegrid')
plt.rcParams["figure.figsize"] = (20,5)  # Changes the size of the graph
sns.boxplot(x='genre', y='revenue', data=movies_by_genre[movies_by_genre['revenue'] < 1000])

# %%
sns.set_style('whitegrid')
plt.rcParams["figure.figsize"] = (20,5)  # Changes the size of the graph
sns.boxplot(x='genre', y='budget', data=movies_by_genre[movies_by_genre['budget'] < 150])

# %%
sns.set_style('whitegrid')
plt.rcParams["figure.figsize"] = (20,5)  # Changes the size of the graph
sns.boxplot(x='genre', y='ROI', data=movies_by_genre[movies_by_genre['ROI'] < 20000])
#sns.boxplot(x='genre', y='ROI', data=movies_by_genre[movies_by_genre['ROI'] < 2000])
#sns.boxplot(x='genre', y='ROI', data=movies_by_genre[movies_by_genre['ROI'] < 100])
# sns.boxplot(x='genre', y='ROI', data=movies_by_genre[movies_by_genre['ROI'] < 50])

# %%
movies_by_genre[['genre', 'ROI']][movies_by_genre['ROI'] < 1000].groupby('genre').describe()
# Out:
#                     ROI                                                      \
#                   count       mean        std       min       25%       50%
# genre
# Action            915.0   2.610393  10.056396 -0.998866  0.042748  1.170408
# Adventure         658.0   3.622426  12.605543 -0.999744  0.194622  1.411362
# Animation         186.0   5.692525  25.621383 -0.998866  0.520001  1.797744
# Comedy           1093.0   4.350234  22.306176 -0.998866  0.100460  1.367685
# Crime             518.0   3.294467  22.532732 -0.994922  0.003667  1.037851
# Documentary        32.0  22.229295  77.313750 -0.965422 -0.142430  2.920980
# Drama            1415.0   4.747008  27.766846 -0.999126 -0.134420  1.103953
# Family            360.0   4.503927  19.076703 -0.999744  0.415171  1.616565
# Fantasy           340.0   4.845790  38.657510 -0.999744  0.290678  1.230590
# History           142.0   3.109704   7.460733 -0.996388 -0.179187  0.898194
# Horror            328.0  13.277118  60.032485 -0.994820  0.356628  1.886369
# Music             108.0   5.567479  14.450679 -0.998641  0.122843  2.126266
# Mystery           261.0   2.579310   6.998952 -0.982069 -0.109046  1.130232
# Romance           562.0   4.161531  10.935636 -0.998641  0.093297  1.430961
# Science Fiction   431.0   4.936654  36.213958 -0.992978  0.069823  1.260046
# Thriller          930.0   4.424132  23.660201 -0.998253 -0.002169  1.178966
# War               116.0   3.975374  12.739420 -0.999126 -0.158417  1.008179
# Western            57.0   3.901748  11.414628 -0.996086 -0.509607  0.800687
#
#
#                        75%         max
# genre
# Action            2.732189  249.000000
# Adventure         3.274062  249.000000
# Animation         3.885434  310.709965
# Comedy            3.424867  499.000000
# Crime             2.653224  499.000000
# Documentary      11.982347  438.616585
# Drama             3.324978  699.000000
# Family            3.857042  310.709965
# Fantasy           3.170359  699.000000
# History           2.530502   56.508517
# Horror            5.436799  699.000000
# Music             5.202962  128.440706
# Mystery           3.045857   85.593058
# Romance           4.080641  128.440706
# Science Fiction   2.983068  699.000000
# Thriller          2.942605  425.644100
# War               3.426263   99.044115
# Western           2.540003   71.500000
